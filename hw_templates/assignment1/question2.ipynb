# %%
counter.next()%R X = rnorm(40) ; Y = rnorm(40) + X ; plot(X,Y, pch=24, bg='red', cex=2)true_false("The correlation is negative.", False, "cor_T_or_F")
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-2-c6d0a624bb28> in <module>()
#       1 get_ipython().magic(u"R X = rnorm(40) ; Y = rnorm(40) + X ; plot(X,Y, pch=24, bg='red', cex=2)")
# ----> 2 true_or_false("The correaltion is negative.", False, "cor_T_or_F")
#
# NameError: name 'true_or_false' is not defined

# %%
counter.next()%R print(summary(lm(X~Y)))

# %%
true_corr = %R cor(X,Y)question_text = r'Up to 2 significant digits, what is the correlation between $X$ and $Y$?'while True:    choices = ['%0.2f' % c for c in list(np.random.random(size=(3,))*2-1) + [true_corr]]    if len(set(choices)) == 4 :        break

# %%
multiple_choice(question_text, choices, "%0.2f" % true_corr, 'correlation')

# %%
publish_display_data('HomeworkBuilder', {'text/html':"<h3>Explain your work</h3>"})

# %%
text_box('Why do you say that?', 'Because.', 'trick_question')
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-1-984367134154> in <module>()
# ----> 1 text_box('Why do you say that?', 'Because.', 'trick_question')
#
# NameError: name 'text_box' is not defined
